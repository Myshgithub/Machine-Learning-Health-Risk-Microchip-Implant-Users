# %%
import pandas as pd

# %%
import csv
import numpy as np

# %%
#pwd
# !ls
# Out:
# dataX.csv  datay.csv  datay.xlsx  sample_data

# %%
pwd
# Out:
# '/content'

# %%
dfx = pd.read_csv("dataX.csv")
dfy = pd.read_csv("datay.csv")

# %%
pwd
# Out:
# '/content'

# %%
ls
# Out:
# dataX.csv  datay.csv  datay.xlsx  sample_data/

# %%
dfx.head()
# Out:
#    gender  migration  medical  disabilities  age  race  religions  degree  \
# 0       2          1        2             3    1     1          1       8
# 1       2          1        1             3    1     1          1       9
# 2       2          1        1             3    2     2          1       7
# 3       1          1        2             3    1     6          1       8
# 4       1          1        2             3    1     2          1       8
#
#          Code1            Code2   Code3      Code4 Code5 Code6 Code7  hrlabel
# 0  health risk  Data Protection     NaN        NaN   NaN   NaN   NaN        1
# 1  health risk  Data Protection     NaN        NaN   NaN   NaN   NaN        1
# 2  health risk      uncertainty  Sshort        NaN   NaN   NaN   NaN        1
# 3          NaN              NaN     NaN        NaN   NaN   NaN   NaN        0
# 4  health risk  Data Protection    Cost  knowledge   NaN   NaN   NaN        1

# %%
dfx.columns
# Out:
# Index(['gender', 'migration', 'medical', 'disabilities', 'age', 'race',
#        'religions', 'degree', 'Code1', 'Code2', 'Code3', 'Code4', 'Code5',
#        'Code6', 'Code7', 'hrlabel'],
#       dtype='object')

# %%
dfx.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 179 entries, 0 to 178
# Data columns (total 16 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   gender        179 non-null    int64
#  1   migration     179 non-null    int64
#  2   medical       179 non-null    int64
#  3   disabilities  179 non-null    int64
#  4   age           179 non-null    int64
#  5   race          179 non-null    int64
#  6   religions     179 non-null    int64
#  7   degree        179 non-null    int64
#  8   Code1         139 non-null    object
#  9   Code2         90 non-null     object
#  10  Code3         43 non-null     object
#  11  Code4         17 non-null     object
#  12  Code5         9 non-null      object
#  13  Code6         4 non-null      object
#  14  Code7         1 non-null      object
#  15  hrlabel       179 non-null    int64
# dtypes: int64(9), object(7)
# memory usage: 22.5+ KB

# %% [markdown]
# #Trian, Test

# %%
from sklearn.model_selection import train_test_split

# %%
dfx.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 179 entries, 0 to 178
# Data columns (total 16 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   gender        179 non-null    int64
#  1   migration     179 non-null    int64
#  2   medical       179 non-null    int64
#  3   disabilities  179 non-null    int64
#  4   age           179 non-null    int64
#  5   race          179 non-null    int64
#  6   religions     179 non-null    int64
#  7   degree        179 non-null    int64
#  8   Code1         139 non-null    object
#  9   Code2         90 non-null     object
#  10  Code3         43 non-null     object
#  11  Code4         17 non-null     object
#  12  Code5         9 non-null      object
#  13  Code6         4 non-null      object
#  14  Code7         1 non-null      object
#  15  hrlabel       179 non-null    int64
# dtypes: int64(9), object(7)
# memory usage: 22.5+ KB

# %%
#Droping columns that are not needed
X = dfx.drop(['Code1','Code2', 'Code3', 'Code4', 'Code5', 'Code6', 'Code7', 'hrlabel'] , axis=1)
y = dfx['hrlabel']

# %%
#Participants Demographic Information
X
# Out:
#      gender  migration  medical  disabilities  age  race  religions  degree
# 0         2          1        2             3    1     1          1       8
# 1         2          1        1             3    1     1          1       9
# 2         2          1        1             3    2     2          1       7
# 3         1          1        2             3    1     6          1       8
# 4         1          1        2             3    1     2          1       8
# ..      ...        ...      ...           ...  ...   ...        ...     ...
# 174       1          0        2             3    1     1          2       7
# 175       2          0        2             3    1     1          2       4
# 176       1          0        1             3    1     1         11       8
# 177       2          1        2             3    1     1          9       5
# 178       1          0        2             3    1     1          2       4
#
# [179 rows x 8 columns]

# %%
# saved X as Excel file


# saved X as CSV file

# %%
dfx.columns
# Out:
# Index(['gender', 'migration', 'medical', 'disabilities', 'age', 'race',
#        'religions', 'degree', 'Code1', 'Code2', 'Code3', 'Code4', 'Code5',
#        'Code6', 'Code7', 'hrlabel'],
#       dtype='object')

# %%
#Taerget Variable (Health Risk)
y
# Out:
# 0      1
# 1      1
# 2      1
# 3      0
# 4      1
#       ..
# 174    1
# 175    0
# 176    0
# 177    0
# 178    0
# Name: hrlabel, Length: 179, dtype: int64

# %%
dfx.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 179 entries, 0 to 178
# Data columns (total 16 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   gender        179 non-null    int64
#  1   migration     179 non-null    int64
#  2   medical       179 non-null    int64
#  3   disabilities  179 non-null    int64
#  4   age           179 non-null    int64
#  5   race          179 non-null    int64
#  6   religions     179 non-null    int64
#  7   degree        179 non-null    int64
#  8   Code1         139 non-null    object
#  9   Code2         90 non-null     object
#  10  Code3         43 non-null     object
#  11  Code4         17 non-null     object
#  12  Code5         9 non-null      object
#  13  Code6         4 non-null      object
#  14  Code7         1 non-null      object
#  15  hrlabel       179 non-null    int64
# dtypes: int64(9), object(7)
# memory usage: 22.5+ KB

# %%
dfx['gender'] = dfx['gender'].astype('object')

# %%
dfx['gender']
# Out:
# 0      2
# 1      2
# 2      2
# 3      1
# 4      1
#       ..
# 174    1
# 175    2
# 176    1
# 177    2
# 178    1
# Name: gender, Length: 179, dtype: object

# %%
#
dfx['gender'].replace(['M','F'],[1,2], inplace=True)
#c.rename_categories({'a': 'A', 'c': 'C'})

# %%
dfx['gender'] = dfx['gender'].astype('category')

# %%
dfx.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 179 entries, 0 to 178
# Data columns (total 16 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   gender        179 non-null    category
#  1   migration     179 non-null    int64
#  2   medical       179 non-null    int64
#  3   disabilities  179 non-null    int64
#  4   age           179 non-null    int64
#  5   race          179 non-null    int64
#  6   religions     179 non-null    int64
#  7   degree        179 non-null    int64
#  8   Code1         139 non-null    object
#  9   Code2         90 non-null     object
#  10  Code3         43 non-null     object
#  11  Code4         17 non-null     object
#  12  Code5         9 non-null      object
#  13  Code6         4 non-null      object
#  14  Code7         1 non-null      object
#  15  hrlabel       179 non-null    int64
# dtypes: category(1), int64(8), object(7)
# memory usage: 21.4+ KB

# %%
df1=dfx #Creating a copy of df for XGBoost because we wanted to change the data type of Cat to int for that model as we got the Error

# %%
dfx['gender']
# Out:
# 0      2
# 1      2
# 2      2
# 3      1
# 4      1
#       ..
# 174    1
# 175    2
# 176    1
# 177    2
# 178    1
# Name: gender, Length: 179, dtype: category
# Categories (2, int64): [1, 2]

# %%
####################################################################
#df['Code1'].value_counts()

# %%
#df["Code1"] = df["Code1"].str.lower()

# %%
##################################################################3
#Starting the Model Training>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30)

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dtree = DecisionTreeClassifier()

# %%
dtree.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier()

# %% [markdown]
# # Predictions

# %%
predictions = dtree.predict(X_test)

# %%
from sklearn.metrics import classification_report,confusion_matrix
print(classification_report(y_test,predictions))
print(confusion_matrix(y_test,predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.42      0.45      0.43        29
#            1       0.30      0.28      0.29        25
#
#     accuracy                           0.37        54
#    macro avg       0.36      0.36      0.36        54
# weighted avg       0.37      0.37      0.37        54
#
# [[13 16]
#  [18  7]]

# %% [markdown]
# ## Tree Visualization

# %%
# !pip install pydot
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: pydot in /usr/local/lib/python3.8/dist-packages (1.3.0)
# Requirement already satisfied: pyparsing>=2.1.4 in /usr/local/lib/python3.8/dist-packages (from pydot) (3.0.9)

# %%
from IPython.display import Image  
#from sklearn.externals.six import StringIO  
from six import StringIO
from sklearn.tree import export_graphviz
import pydot 

features = list(X.columns)
features
# Out:
# ['gender',
#  'migration',
#  'medical',
#  'disabilities',
#  'age',
#  'race',
#  'religions',
#  'degree']

# %%
dot_data = StringIO()  
export_graphviz(dtree, out_file=dot_data,feature_names=features,filled=True,rounded=True)

graph = pydot.graph_from_dot_data(dot_data.getvalue())  
Image(graph[0].create_png())

# %% [markdown]
# #Purunning the Decision Tree

# %%
import os
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.model_selection import RandomizedSearchCV, GridSearchCV
from sklearn import tree
from sklearn.metrics import accuracy_score,confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#Train, Test Data again for Purunning:
x_train,x_test,y_train,y_test = train_test_split(X,y,stratify=y)
print(x_train.shape)
print(x_test.shape)
# Out:
# (134, 8)
# (45, 8)

# %%
#we will fit a normal decision tree without any fine tuning and check the results
clf = tree.DecisionTreeClassifier(random_state=0)
clf.fit(x_train,y_train)
y_train_pred = clf.predict(x_train)
y_test_pred = clf.predict(x_test)

# %%
dfx.columns
# Out:
# Index(['gender', 'migration', 'medical', 'disabilities', 'age', 'race',
#        'religions', 'degree', 'Code1', 'Code2', 'Code3', 'Code4', 'Code5',
#        'Code6', 'Code7', 'hrlabel'],
#       dtype='object')

# %%
#Visualizing decision tree
plt.figure(figsize=(30,30))
#features = df.columns
classes = ['Not health risk','hearlth risk']
tree.plot_tree(clf,feature_names=features,class_names=classes,filled=True)
plt.show()

# %%
# helper function
def plot_confusionmatrix(y_train_pred,y_train,dom):
    print(f'{dom} Confusion matrix')
    cf = confusion_matrix(y_train_pred,y_train)
    sns.heatmap(cf,annot=True,yticklabels=classes
               ,xticklabels=classes,cmap='Reds', fmt='g')
    plt.tight_layout()
    plt.show()

# %%
print(f'Train score {accuracy_score(y_train_pred,y_train)}')
print(f'Test score {accuracy_score(y_test_pred,y_test)}')
plot_confusionmatrix(y_train_pred,y_train,dom='Train')
plot_confusionmatrix(y_test_pred,y_test,dom='Test')
# Out:
# Train score 0.9477611940298507
# Test score 0.5111111111111111
# Train Confusion matrix
# Test Confusion matrix

# %%
#Pre pruning techniques
params = {'max_depth': [2,4,6,8,10,12],
         'min_samples_split': [2,3,4],
         'min_samples_leaf': [1,2]}

clf = tree.DecisionTreeClassifier()
gcv = GridSearchCV(estimator=clf,param_grid=params)
gcv.fit(x_train,y_train)
# Out:
# GridSearchCV(estimator=DecisionTreeClassifier(),
#              param_grid={'max_depth': [2, 4, 6, 8, 10, 12],
#                          'min_samples_leaf': [1, 2],
#                          'min_samples_split': [2, 3, 4]})

# %%
GridSearchCV(estimator=DecisionTreeClassifier(),
             param_grid={'max_depth': [2, 4, 6, 8, 10, 12],
                         'min_samples_leaf': [1, 2],
                         'min_samples_split': [2, 3, 4]})
# Out:
# GridSearchCV(estimator=DecisionTreeClassifier(),
#              param_grid={'max_depth': [2, 4, 6, 8, 10, 12],
#                          'min_samples_leaf': [1, 2],
#                          'min_samples_split': [2, 3, 4]})

# %%
model = gcv.best_estimator_
model.fit(x_train,y_train)
y_train_pred = model.predict(x_train)
y_test_pred = model.predict(x_test)

print(f'Train score {accuracy_score(y_train_pred,y_train)}')
print(f'Test score {accuracy_score(y_test_pred,y_test)}')
plot_confusionmatrix(y_train_pred,y_train,dom='Train')
plot_confusionmatrix(y_test_pred,y_test,dom='Test')
# Out:
# Train score 0.8283582089552238
# Test score 0.4888888888888889
# Train Confusion matrix
# Test Confusion matrix

# %%
model #The best case
# Out:
# DecisionTreeClassifier(max_depth=12, min_samples_leaf=2)

# %%
X
# Out:
#      gender  migration  medical  disabilities  age  race  religions  degree
# 0         2          1        2             3    1     1          1       8
# 1         2          1        1             3    1     1          1       9
# 2         2          1        1             3    2     2          1       7
# 3         1          1        2             3    1     6          1       8
# 4         1          1        2             3    1     2          1       8
# ..      ...        ...      ...           ...  ...   ...        ...     ...
# 174       1          0        2             3    1     1          2       7
# 175       2          0        2             3    1     1          2       4
# 176       1          0        1             3    1     1         11       8
# 177       2          1        2             3    1     1          9       5
# 178       1          0        2             3    1     1          2       4
#
# [179 rows x 8 columns]

# %%
X.columns
# Out:
# Index(['gender', 'migration', 'medical', 'disabilities', 'age', 'race',
#        'religions', 'degree'],
#       dtype='object')

# %%
features
# Out:
# ['gender',
#  'migration',
#  'medical',
#  'disabilities',
#  'age',
#  'race',
#  'religions',
#  'degree']

# %%
#Visualization after Puruning:
plt.figure(figsize=(30,30))
#features = df.columns
classes = ['No health risk','health risk']
tree.plot_tree(model,feature_names=features,class_names=classes,filled=True)
plt.show()

# %%
#After prunning Calculation (Added by Sh(me))
#from sklearn.metrics import classification_report,confusion_matrix
print(classification_report(y_test,y_test_pred))
#print(confusion_matrix(y_test,predictions))
print(confusion_matrix(y_test,y_test_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.48      0.68      0.57        22
#            1       0.50      0.30      0.38        23
#
#     accuracy                           0.49        45
#    macro avg       0.49      0.49      0.47        45
# weighted avg       0.49      0.49      0.47        45
#
# [[15  7]
#  [16  7]]
